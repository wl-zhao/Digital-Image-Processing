# %%
from ImagePreprocesser import ImagePreprocesser
from os.path import expanduser
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.transform import resize
from keras.preprocessing.image import img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
image_dir = expanduser("~") + '/imagenet/resized/'
imagePreprocesser = ImagePreprocesser(image_dir, True)
# Out:
# start init
# init done

# %%
imagePreprocesser.preprocess_data(8000, 8000, expanduser("~") + '/imagenet/tfrecords/')
# Out:
# writing0.tfrecords
# /home/zwl/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 1/1 [==============================] - 3s 3s/step
# image n00141669_2620.jpg done 0
# 1/1 [==============================] - 0s 35ms/step
# image n00288000_11012.jpg done 1
# 1/1 [==============================] - 0s 39ms/step
# image n00288000_12766.jpg done 2
# 1/1 [==============================] - 0s 34ms/step
# image n00006484_1913.jpg done 3
# 1/1 [==============================] - 0s 39ms/step
# image n00141669_6708.jpg done 4
# 1/1 [==============================] - 0s 39ms/step
# image n00021939_15210.jpg done 5
# 1/1 [==============================] - 0s 40ms/step
# image n00445802_1858.jpg done 6
# 1/1 [==============================] - 0s 40ms/step
# image n00120010_16187.jpg done 7
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
image = load_img(expanduser('~' + '/imagenet/test.jpg'))
array = img_to_array(image)
array = resize(array, (224, 224), anti_aliasing=True)
# plt.imshow(array / 255)
image_lab = rgb2lab(array / 255)
image_gray = rgb2gray(array).astype(np.uint8)
# print(gray2rgb(image_gray))
plt.imshow(gray2rgb(image_gray))
image_gray = image_gray * 100.0 / 255.0
shape = image_gray.shape + (3,)
np.array(image_gray.shape).astype(np.uint16)
# Out:
# /home/zwl/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# array([224, 224], dtype=uint16)

# %%
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean

image = color.rgb2gray(data.astronaut())

image_rescaled = rescale(image, 1.0 / 4.0, anti_aliasing=False)
# Out:
# /home/zwl/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# /home/zwl/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# array([[5.83434902e-01, 4.14859216e-01, 2.44058431e-01, ...,
#         4.75007843e-01, 4.58213333e-01, 4.69121961e-01],
#        [6.75588235e-01, 5.56006667e-01, 4.49052941e-01, ...,
#         4.68548627e-01, 4.56501176e-01, 4.55958431e-01],
#        [7.66334902e-01, 7.00524314e-01, 6.49276078e-01, ...,
#         4.76406667e-01, 4.62104314e-01, 4.53978431e-01],
#        ...,
# ...

# %%
combined = np.zeros(shape)
combined[:, :, 0] = image_gray
combined[:, :, 1:] = image_lab[:, :, 1:]
plt.imshow(lab2rgb(combined))
